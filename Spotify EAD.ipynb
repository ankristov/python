# %% [markdown]
# Origin: https://blog.devgenius.io/spotify-data-analysis-with-python-a727542beaa7
#
# Intro
# It turns out Spotify has an outstanding API to connect you to its ubiquitous database of songs and their features. You can, for example, get visual insights from songs you love or integrate a playback into your web application. There is also a powerful song search engine available as well as a recommendation system which helps you listen to more of what you love.
#
# Prerequisites
# Let’s start off with signing up at the Spotify official website for zero cost and little effort.
#
# Next, open your application dashboard and hit the “Create an app” button. Input the necessary details and prepare to explore.
#
# Grab your ClientID and Client Secret and start your favourite Python IDE. It’s time to code.
#
# We are going to use a wrapper utility around Spotify API called SpotiPy to make handsome one-line-long requests instead of explicitly reaching the endpoints. Let’s install it.

# %%
# Spotify app https://developer.spotify.com/dashboard/applications/eadc1f958a3b40f8866b69c9eda72b86
CLIENT_ID = 'eadc1f958a3b40f8866b69c9eda72b86'
CLIENT_SECRET = '89ba3f2e339040c0933f7f46b491fdb9'

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in ./lib/python3.7/site-packages (2.20.0)
# Requirement already satisfied: six>=1.15.0 in ./lib/python3.7/site-packages (from spotipy) (1.15.0)
# Requirement already satisfied: requests>=2.25.0 in ./lib/python3.7/site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: urllib3>=1.26.0 in ./lib/python3.7/site-packages (from spotipy) (1.26.11)
# Requirement already satisfied: redis>=3.5.3 in ./lib/python3.7/site-packages (from spotipy) (4.3.4)
# Requirement already satisfied: importlib-metadata>=1.0 in ./lib/python3.7/site-packages (from redis>=3.5.3->spotipy) (4.8.2)
# Requirement already satisfied: typing-extensions in ./lib/python3.7/site-packages (from redis>=3.5.3->spotipy) (3.10.0.2)
# Requirement already satisfied: deprecated>=1.2.3 in ./lib/python3.7/site-packages (from redis>=3.5.3->spotipy) (1.2.13)
# Requirement already satisfied: packaging>=20.4 in ./lib/python3.7/site-packages (from redis>=3.5.3->spotipy) (21.2)
# Requirement already satisfied: async-timeout>=4.0.2 in ./lib/python3.7/site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.7/site-packages (from requests>=2.25.0->spotipy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.7/site-packages (from requests>=2.25.0->spotipy) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./lib/python3.7/site-packages (from requests>=2.25.0->spotipy) (2.1.0)
# Requirement already satisfied: wrapt<2,>=1.10 in ./lib/python3.7/site-packages (from deprecated>=1.2.3->redis>=3.5.3->spotipy) (1.14.1)
# Requirement already satisfied: zipp>=0.5 in ./lib/python3.7/site-packages (from importlib-metadata>=1.0->redis>=3.5.3->spotipy) (3.6.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in ./lib/python3.7/site-packages (from packaging>=20.4->redis>=3.5.3->spotipy) (2.4.7)
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id = CLIENT_ID, client_secret = CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager, requests_timeout = 120)
print(sp.__dir__())
# Out:
# ['prefix', '_auth', 'client_credentials_manager', 'oauth_manager', '_auth_manager', 'proxies', 'requests_timeout', 'status_forcelist', 'backoff_factor', 'retries', 'status_retries', 'language', '_session', '__module__', '__doc__', 'max_retries', 'default_retry_codes', 'country_codes', '__init__', 'set_auth', 'auth_manager', '__del__', '_build_session', '_auth_headers', '_internal_call', '_get', '_post', '_delete', '_put', 'next', 'previous', 'track', 'tracks', 'artist', 'artists', 'artist_albums', 'artist_top_tracks', 'artist_related_artists', 'album', 'album_tracks', 'albums', 'show', 'shows', 'show_episodes', 'episode', 'episodes', 'search', 'search_markets', 'user', 'current_user_playlists', 'playlist', 'playlist_tracks', 'playlist_items', 'playlist_cover_image', 'playlist_upload_cover_image', 'user_playlist', 'user_playlist_tracks', 'user_playlists', 'user_playlist_create', 'user_playlist_change_details', 'user_playlist_unfollow', 'user_playlist_add_tracks', 'user_playlist_replace_tracks', 'user_playlist_reorder_tracks', 'user_playlist_remove_all_occurrences_of_tracks', 'user_playlist_remove_specific_occurrences_of_tracks', 'user_playlist_follow_playlist', 'user_playlist_is_following', 'playlist_change_details', 'current_user_unfollow_playlist', 'playlist_add_items', 'playlist_replace_items', 'playlist_reorder_items', 'playlist_remove_all_occurrences_of_items', 'playlist_remove_specific_occurrences_of_items', 'current_user_follow_playlist', 'playlist_is_following', 'me', 'current_user', 'current_user_playing_track', 'current_user_saved_albums', 'current_user_saved_albums_add', 'current_user_saved_albums_delete', 'current_user_saved_albums_contains', 'current_user_saved_tracks', 'current_user_saved_tracks_add', 'current_user_saved_tracks_delete', 'current_user_saved_tracks_contains', 'current_user_saved_episodes', 'current_user_saved_episodes_add', 'current_user_saved_episodes_delete', 'current_user_saved_episodes_contains', 'current_user_saved_shows', 'current_user_saved_shows_add', 'current_user_saved_shows_delete', 'current_user_saved_shows_contains', 'current_user_followed_artists', 'current_user_following_artists', 'current_user_following_users', 'current_user_top_artists', 'current_user_top_tracks', 'current_user_recently_played', 'user_follow_artists', 'user_follow_users', 'user_unfollow_artists', 'user_unfollow_users', 'featured_playlists', 'new_releases', 'category', 'categories', 'category_playlists', 'recommendations', 'recommendation_genre_seeds', 'audio_analysis', 'audio_features', 'devices', 'current_playback', 'currently_playing', 'transfer_playback', 'start_playback', 'pause_playback', 'next_track', 'previous_track', 'seek_track', 'repeat', 'volume', 'shuffle', 'add_to_queue', 'available_markets', '_append_device_id', '_get_id', '_get_uri', '_is_uri', '_search_multiple_markets', '__dict__', '__weakref__', '__repr__', '__hash__', '__str__', '__getattribute__', '__setattr__', '__delattr__', '__lt__', '__le__', '__eq__', '__ne__', '__gt__', '__ge__', '__new__', '__reduce_ex__', '__reduce__', '__subclasshook__', '__init_subclass__', '__format__', '__sizeof__', '__dir__', '__class__']

# %% [markdown]
# Fetch Tracks and Artists
# The next step is data querying. Note that we can only fetch information about 50 or less tracks at a time. The q parameter in the sp.search() method is where you can search for specific items. The reference is here (https://developer.spotify.com/documentation/web-api/reference/#/operations/search).

# %%
import pprint
track_results = sp.search(q='year:2022', type='track',limit=50,offset=0)
pprint.pprint(track_results['tracks']['items'])
# Out:
# [{'album': {'album_type': 'album',
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#                          'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#                          'id': '4q3ewBCX7sLwd24euuV69X',
#                          'name': 'Bad Bunny',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AG',
#                                   'AL',
#                                   'AM',
#                                   'AO',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'AZ',
#                                   'BA',
#                                   'BB',
#                                   'BD',
#                                   'BE',
#                                   'BF',
#                                   'BG',
#                                   'BH',
#                                   'BI',
#                                   'BJ',
#                                   'BN',
#                                   'BO',
#                                   'BR',
#                                   'BS',
#                                   'BT',
#                                   'BW',
#                                   'BY',
#                                   'BZ',
#                                   'CA',
#                                   'CD',
#                                   'CG',
#                                   'CH',
#                                   'CI',
#                                   'CL',
#                                   'CM',
#                                   'CO',
#                                   'CR',
#                                   'CV',
#                                   'CW',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DJ',
#                                   'DK',
#                                   'DM',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FJ',
#                                   'FM',
#                                   'FR',
#                                   'GA',
#                                   'GB',
#                                   'GD',
#                                   'GE',
#                                   'GH',
#                                   'GM',
#                                   'GN',
#                                   'GQ',
#                                   'GR',
#                                   'GT',
#                                   'GW',
#                                   'GY',
#                                   'HK',
#                                   'HN',
#                                   'HR',
#                                   'HT',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IQ',
#                                   'IS',
#                                   'IT',
#                                   'JM',
#                                   'JO',
#                                   'JP',
#                                   'KE',
#                                   'KG',
#                                   'KH',
#                                   'KI',
#                                   'KM',
#                                   'KN',
#                                   'KR',
#                                   'KW',
#                                   'KZ',
#                                   'LA',
#                                   'LB',
#                                   'LC',
#                                   'LI',
#                                   'LK',
#                                   'LR',
#                                   'LS',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'LY',
#                                   'MA',
#                                   'MC',
#                                   'MD',
#                                   'ME',
#                                   'MG',
#                                   'MH',
#                                   'MK',
#                                   'ML',
#                                   'MN',
#                                   'MO',
#                                   'MR',
#                                   'MT',
#                                   'MU',
#                                   'MV',
#                                   'MW',
#                                   'MX',
#                                   'MY',
#                                   'MZ',
#                                   'NA',
#                                   'NE',
#                                   'NG',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NP',
#                                   'NR',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PG',
#                                   'PH',
#                                   'PK',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PW',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'RS',
#                                   'RW',
#                                   'SA',
#                                   'SB',
#                                   'SC',
#                                   'SE',
#                                   'SG',
#                                   'SI',
#                                   'SK',
#                                   'SL',
#                                   'SM',
#                                   'SN',
#                                   'SR',
#                                   'ST',
#                                   'SV',
#                                   'SZ',
#                                   'TD',
#                                   'TG',
#                                   'TH',
#                                   'TJ',
#                                   'TL',
#                                   'TN',
#                                   'TO',
#                                   'TR',
#                                   'TT',
#                                   'TV',
#                                   'TW',
#                                   'TZ',
#                                   'UA',
#                                   'UG',
#                                   'US',
#                                   'UY',
#                                   'UZ',
#                                   'VC',
#                                   'VE',
#                                   'VN',
#                                   'VU',
#                                   'WS',
#                                   'XK',
#                                   'ZA',
#                                   'ZM',
#                                   'ZW'],
#             'external_urls': {'spotify': 'https://open.spotify.com/album/3RQQmkQEvNCY4prGKE6oc5'},
#             'href': 'https://api.spotify.com/v1/albums/3RQQmkQEvNCY4prGKE6oc5',
#             'id': '3RQQmkQEvNCY4prGKE6oc5',
#             'images': [{'height': 640,
#                         'url': 'https://i.scdn.co/image/ab67616d0000b27349d694203245f241a1bcaa72',
#                         'width': 640},
#                        {'height': 300,
#                         'url': 'https://i.scdn.co/image/ab67616d00001e0249d694203245f241a1bcaa72',
#                         'width': 300},
#                        {'height': 64,
#                         'url': 'https://i.scdn.co/image/ab67616d0000485149d694203245f241a1bcaa72',
#                         'width': 64}],
#             'name': 'Un Verano Sin Ti',
#             'release_date': '2022-05-06',
#             'release_date_precision': 'day',
#             'total_tracks': 23,
#             'type': 'album',
#             'uri': 'spotify:album:3RQQmkQEvNCY4prGKE6oc5'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#                'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#                'id': '4q3ewBCX7sLwd24euuV69X',
#                'name': 'Bad Bunny',
#                'type': 'artist',
#                'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#               {'external_urls': {'spotify': 'https://open.spotify.com/artist/37230BxxYs9ksS7OkZw3IU'},
#                'href': 'https://api.spotify.com/v1/artists/37230BxxYs9ksS7OkZw3IU',
#                'id': '37230BxxYs9ksS7OkZw3IU',
#                'name': 'Chencho Corleone',
#                'type': 'artist',
#                'uri': 'spotify:artist:37230BxxYs9ksS7OkZw3IU'}],
#   'available_markets': ['AD',
#                         'AE',
#                         'AG',
#                         'AL',
#                         'AM',
#                         'AO',
#                         'AR',
#                         'AT',
#                         'AU',
#                         'AZ',
#                         'BA',
#                         'BB',
#                         'BD',
#                         'BE',
#                         'BF',
#                         'BG',
#                         'BH',
#                         'BI',
#                         'BJ',
#                         'BN',
#                         'BO',
#                         'BR',
#                         'BS',
#                         'BT',
#                         'BW',
#                         'BY',
#                         'BZ',
#                         'CA',
#                         'CD',
#                         'CG',
#                         'CH',
#                         'CI',
#                         'CL',
#                         'CM',
#                         'CO',
#                         'CR',
#                         'CV',
#                         'CW',
#                         'CY',
#                         'CZ',
#                         'DE',
#                         'DJ',
#                         'DK',
#                         'DM',
#                         'DO',
#                         'DZ',
#                         'EC',
#                         'EE',
#                         'EG',
#                         'ES',
#                         'FI',
#                         'FJ',
#                         'FM',
#                         'FR',
#                         'GA',
#                         'GB',
#                         'GD',
#                         'GE',
#                         'GH',
#                         'GM',
#                         'GN',
#                         'GQ',
#                         'GR',
#                         'GT',
#                         'GW',
#                         'GY',
#                         'HK',
#                         'HN',
#                         'HR',
#                         'HT',
#                         'HU',
#                         'ID',
#                         'IE',
#                         'IL',
#                         'IN',
#                         'IQ',
#                         'IS',
#                         'IT',
#                         'JM',
#                         'JO',
#                         'JP',
#                         'KE',
#                         'KG',
#                         'KH',
#                         'KI',
#                         'KM',
#                         'KN',
#                         'KR',
#                         'KW',
#                         'KZ',
#                         'LA',
#                         'LB',
#                         'LC',
#                         'LI',
#                         'LK',
#                         'LR',
#                         'LS',
#                         'LT',
#                         'LU',
#                         'LV',
#                         'LY',
#                         'MA',
#                         'MC',
#                         'MD',
#                         'ME',
#                         'MG',
#                         'MH',
#                         'MK',
#                         'ML',
#                         'MN',
#                         'MO',
#                         'MR',
#                         'MT',
#                         'MU',
#                         'MV',
#                         'MW',
#                         'MX',
#                         'MY',
#                         'MZ',
#                         'NA',
#                         'NE',
#                         'NG',
#                         'NI',
#                         'NL',
#                         'NO',
#                         'NP',
#                         'NR',
#                         'NZ',
#                         'OM',
#                         'PA',
#                         'PE',
#                         'PG',
#                         'PH',
#                         'PK',
#                         'PL',
#                         'PS',
#                         'PT',
#                         'PW',
#                         'PY',
#                         'QA',
#                         'RO',
#                         'RS',
#                         'RW',
#                         'SA',
#                         'SB',
#                         'SC',
#                         'SE',
#                         'SG',
#                         'SI',
#                         'SK',
#                         'SL',
#                         'SM',
#                         'SN',
#                         'SR',
#                         'ST',
#                         'SV',
#                         'SZ',
#                         'TD',
#                         'TG',
#                         'TH',
#                         'TJ',
#                         'TL',
#                         'TN',
#                         'TO',
#                         'TR',
#                         'TT',
#                         'TV',
#                         'TW',
#                         'TZ',
#                         'UA',
#                         'UG',
#                         'US',
#                         'UY',
#                         'UZ',
#                         'VC',
#                         'VE',
#                         'VN',
#                         'VU',
#                         'WS',
#                         'XK',
#                         'ZA',
#                         'ZM',
#                         'ZW'],
#   'disc_number': 1,
#   'duration_ms': 178567,
#   'explicit': True,
#   'external_ids': {'isrc': 'QM6MZ2214877'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6Sq7ltF9Qa7SNFBsV5Cogx'},
#   'href': 'https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#   'is_local': False,
#   'name': 'Me Porto Bonito',
#   'popularity': 99,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8513b15fb5b39966d8eccaa7b8c050c7a570e6e8?cid=eadc1f958a3b40f8866b69c9eda72b86',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx'},
#  {'album': {'album_type': 'album',
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27rjDVGfZG4eorQwrZt2ZD'},
#                          'href': 'https://api.spotify.com/v1/artists/27rjDVGfZG4eorQwrZt2ZD',
#                          'id': '27rjDVGfZG4eorQwrZt2ZD',
#                          'name': 'Ish Kevin',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:27rjDVGfZG4eorQwrZt2ZD'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AG',
#                                   'AL',
#                                   'AM',
#                                   'AO',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'AZ',
#                                   'BA',
#                                   'BB',
#                                   'BD',
#                                   'BE',
#                                   'BF',
#                                   'BG',
#                                   'BH',
#                                   'BI',
#                                   'BJ',
#                                   'BN',
#                                   'BO',
#                                   'BR',
#                                   'BS',
#                                   'BT',
#                                   'BW',
#                                   'BY',
#                                   'BZ',
#                                   'CA',
#                                   'CD',
#                                   'CG',
#                                   'CH',
#                                   'CI',
#                                   'CL',
#                                   'CM',
#                                   'CO',
#                                   'CR',
#                                   'CV',
#                                   'CW',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DJ',
#                                   'DK',
#                                   'DM',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FJ',
#                                   'FM',
#                                   'FR',
#                                   'GA',
#                                   'GB',
#                                   'GD',
#                                   'GE',
#                                   'GH',
#                                   'GM',
#                                   'GN',
#                                   'GQ',
#                                   'GR',
#                                   'GT',
#                                   'GW',
#                                   'GY',
#                                   'HK',
#                                   'HN',
#                                   'HR',
#                                   'HT',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IQ',
#                                   'IS',
#                                   'IT',
#                                   'JM',
#                                   'JO',
#                                   'JP',
#                                   'KE',
#                                   'KG',
#                                   'KH',
#                                   'KI',
#                                   'KM',
#                                   'KN',
#                                   'KR',
#                                   'KW',
#                                   'KZ',
#                                   'LA',
#                                   'LB',
#                                   'LC',
#                                   'LI',
#                                   'LK',
#                                   'LR',
#                                   'LS',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'LY',
#                                   'MA',
#                                   'MC',
#                                   'MD',
#                                   'ME',
#                                   'MG',
#                                   'MH',
#                                   'MK',
#                                   'ML',
#                                   'MN',
#                                   'MO',
#                                   'MR',
#                                   'MT',
#                                   'MU',
#                                   'MV',
#                                   'MW',
#                                   'MX',
#                                   'MY',
#                                   'MZ',
#                                   'NA',
#                                   'NE',
#                                   'NG',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NP',
#                                   'NR',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PG',
#                                   'PH',
#                                   'PK',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PW',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'RS',
#                                   'RW',
#                                   'SA',
#                                   'SB',
#                                   'SC',
#                                   'SE',
#                                   'SG',
#                                   'SI',
#                                   'SK',
#                                   'SL',
#                                   'SM',
#                                   'SN',
#                                   'SR',
#                                   'ST',
#                                   'SV',
#                                   'SZ',
#                                   'TD',
#                                   'TG',
#                                   'TH',
#                                   'TJ',
#                                   'TL',
#                                   'TN',
#                                   'TO',
#                                   'TR',
#                                   'TT',
#                                   'TV',
#                                   'TW',
#                                   'TZ',
#                                   'UA',
#                                   'UG',
#                                   'US',
#                                   'UY',
#                                   'UZ',
#                                   'VC',
#                                   'VE',
#                                   'VN',
#                                   'VU',
#                                   'WS',
#                                   'XK',
#                                   'ZA',
#                                   'ZM',
#                                   'ZW'],
#             'external_urls': {'spotify': 'https://open.spotify.com/album/6iKEj6dNNKq4O0doi6GjVR'},
#             'href': 'https://api.spotify.com/v1/albums/6iKEj6dNNKq4O0doi6GjVR',
#             'id': '6iKEj6dNNKq4O0doi6GjVR',
#             'images': [{'height': 640,
#                         'url': 'https://i.scdn.co/image/ab67616d0000b2737939184be6c353104c1f60c2',
#                         'width': 640},
#                        {'height': 300,
#                         'url': 'https://i.scdn.co/image/ab67616d00001e027939184be6c353104c1f60c2',
#                         'width': 300},
#                        {'height': 64,
#                         'url': 'https://i.scdn.co/image/ab67616d000048517939184be6c353104c1f60c2',
#                         'width': 64}],
#             'name': 'Trappish II',
#             'release_date': '2022-03-25',
#             'release_date_precision': 'day',
#             'total_tracks': 7,
#             'type': 'album',
#             'uri': 'spotify:album:6iKEj6dNNKq4O0doi6GjVR'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27rjDVGfZG4eorQwrZt2ZD'},
#                'href': 'https://api.spotify.com/v1/artists/27rjDVGfZG4eorQwrZt2ZD',
#                'id': '27rjDVGfZG4eorQwrZt2ZD',
#                'name': 'Ish Kevin',
#                'type': 'artist',
#                'uri': 'spotify:artist:27rjDVGfZG4eorQwrZt2ZD'}],
#   'available_markets': ['AD',
#                         'AE',
#                         'AG',
#                         'AL',
#                         'AM',
#                         'AO',
#                         'AR',
#                         'AT',
#                         'AU',
#                         'AZ',
#                         'BA',
#                         'BB',
#                         'BD',
#                         'BE',
#                         'BF',
#                         'BG',
#                         'BH',
#                         'BI',
#                         'BJ',
#                         'BN',
#                         'BO',
#                         'BR',
#                         'BS',
#                         'BT',
#                         'BW',
#                         'BY',
#                         'BZ',
#                         'CA',
#                         'CD',
#                         'CG',
#                         'CH',
#                         'CI',
#                         'CL',
#                         'CM',
#                         'CO',
#                         'CR',
#                         'CV',
#                         'CW',
#                         'CY',
#                         'CZ',
#                         'DE',
#                         'DJ',
#                         'DK',
#                         'DM',
#                         'DO',
#                         'DZ',
#                         'EC',
#                         'EE',
#                         'EG',
#                         'ES',
#                         'FI',
#                         'FJ',
#                         'FM',
#                         'FR',
#                         'GA',
#                         'GB',
#                         'GD',
#                         'GE',
#                         'GH',
#                         'GM',
#                         'GN',
#                         'GQ',
#                         'GR',
#                         'GT',
#                         'GW',
#                         'GY',
#                         'HK',
#                         'HN',
#                         'HR',
#                         'HT',
#                         'HU',
#                         'ID',
#                         'IE',
#                         'IL',
#                         'IN',
#                         'IQ',
#                         'IS',
#                         'IT',
#                         'JM',
#                         'JO',
#                         'JP',
#                         'KE',
#                         'KG',
#                         'KH',
#                         'KI',
#                         'KM',
#                         'KN',
#                         'KR',
#                         'KW',
#                         'KZ',
#                         'LA',
#                         'LB',
#                         'LC',
#                         'LI',
#                         'LK',
#                         'LR',
#                         'LS',
#                         'LT',
#                         'LU',
#                         'LV',
#                         'LY',
#                         'MA',
#                         'MC',
#                         'MD',
#                         'ME',
#                         'MG',
#                         'MH',
#                         'MK',
#                         'ML',
#                         'MN',
#                         'MO',
#                         'MR',
#                         'MT',
#                         'MU',
#                         'MV',
#                         'MW',
#                         'MX',
#                         'MY',
#                         'MZ',
#                         'NA',
#                         'NE',
#                         'NG',
#                         'NI',
#                         'NL',
#                         'NO',
#                         'NP',
#                         'NR',
#                         'NZ',
#                         'OM',
#                         'PA',
#                         'PE',
#                         'PG',
#                         'PH',
#                         'PK',
#                         'PL',
#                         'PS',
#                         'PT',
#                         'PW',
#                         'PY',
#                         'QA',
#                         'RO',
#                         'RS',
#                         'RW',
#                         'SA',
#                         'SB',
#                         'SC',
#                         'SE',
#                         'SG',
#                         'SI',
#                         'SK',
#                         'SL',
#                         'SM',
#                         'SN',
#                         'SR',
#                         'ST',
#                         'SV',
#                         'SZ',
#                         'TD',
#                         'TG',
#                         'TH',
#                         'TJ',
#                         'TL',
#                         'TN',
#                         'TO',
#                         'TR',
#                         'TT',
#                         'TV',
#                         'TW',
#                         'TZ',
#                         'UA',
#                         'UG',
#                         'US',
#                         'UY',
#                         'UZ',
#                         'VC',
#                         'VE',
#                         'VN',
#                         'VU',
#                         'WS',
#                         'XK',
#                         'ZA',
#                         'ZM',
#                         'ZW'],
#   'disc_number': 1,
#   'duration_ms': 161807,
#   'explicit': True,
#   'external_ids': {'isrc': 'QZGLM2204071'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4eHkG6yWQ4pD0zqVkV0R5a'},
#   'href': 'https://api.spotify.com/v1/tracks/4eHkG6yWQ4pD0zqVkV0R5a',
#   'id': '4eHkG6yWQ4pD0zqVkV0R5a',
#   'is_local': False,
#   'name': 'My Year (2022)',
#   'popularity': 21,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4c35af7ff98504fd53dde8819bcefc728ac6c3fb?cid=eadc1f958a3b40f8866b69c9eda72b86',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:4eHkG6yWQ4pD0zqVkV0R5a'},
#  {'album': {'album_type': 'album',
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2LIk90788K0zvyj2JJVwkJ'},
#                          'href': 'https://api.spotify.com/v1/artists/2LIk90788K0zvyj2JJVwkJ',
#                          'id': '2LIk90788K0zvyj2JJVwkJ',
#                          'name': 'Jack Harlow',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:2LIk90788K0zvyj2JJVwkJ'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AG',
#                                   'AL',
#                                   'AM',
#                                   'AO',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'AZ',
#                                   'BA',
#                                   'BB',
#                                   'BD',
#                                   'BE',
#                                   'BF',
#                                   'BG',
#                                   'BH',
#                                   'BI',
#                                   'BJ',
#                                   'BN',
#                                   'BO',
#                                   'BR',
#                                   'BS',
#                                   'BT',
#                                   'BW',
#                                   'BZ',
#                                   'CA',
#                                   'CD',
#                                   'CG',
#                                   'CH',
#                                   'CI',
#                                   'CL',
#                                   'CM',
#                                   'CO',
#                                   'CR',
#                                   'CV',
#                                   'CW',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DJ',
#                                   'DK',
#                                   'DM',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FJ',
#                                   'FM',
#                                   'FR',
#                                   'GA',
#                                   'GB',
#                                   'GD',
#                                   'GE',
#                                   'GH',
#                                   'GM',
#                                   'GN',
#                                   'GQ',
#                                   'GR',
#                                   'GT',
#                                   'GW',
#                                   'GY',
#                                   'HK',
#                                   'HN',
#                                   'HR',
#                                   'HT',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IQ',
#                                   'IS',
#                                   'IT',
#                                   'JM',
#                                   'JO',
#                                   'JP',
#                                   'KE',
#                                   'KG',
#                                   'KH',
#                                   'KI',
#                                   'KM',
#                                   'KN',
#                                   'KR',
#                                   'KW',
#                                   'KZ',
#                                   'LA',
#                                   'LB',
#                                   'LC',
#                                   'LI',
#                                   'LK',
#                                   'LR',
#                                   'LS',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'LY',
#                                   'MA',
#                                   'MC',
#                                   'MD',
#                                   'ME',
#                                   'MG',
#                                   'MH',
#                                   'MK',
#                                   'ML',
#                                   'MN',
#                                   'MO',
#                                   'MR',
#                                   'MT',
#                                   'MU',
#                                   'MV',
#                                   'MW',
#                                   'MX',
#                                   'MY',
#                                   'MZ',
#                                   'NA',
#                                   'NE',
#                                   'NG',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NP',
#                                   'NR',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PG',
#                                   'PH',
#                                   'PK',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PW',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'RS',
#                                   'RW',
#                                   'SA',
#                                   'SB',
#                                   'SC',
#                                   'SE',
#                                   'SG',
#                                   'SI',
#                                   'SK',
#                                   'SL',
#                                   'SM',
#                                   'SN',
#                                   'SR',
#                                   'ST',
#                                   'SV',
#                                   'SZ',
#                                   'TD',
#                                   'TG',
#                                   'TH',
#                                   'TJ',
#                                   'TL',
#                                   'TN',
#                                   'TO',
#                                   'TR',
#                                   'TT',
#                                   'TV',
#                                   'TW',
#                                   'TZ',
#                                   'UA',
#                                   'UG',
#                                   'US',
#                                   'UY',
#                                   'UZ',
#                                   'VC',
#                                   'VE',
#                                   'VN',
#                                   'VU',
#                                   'WS',
#                                   'XK',
#                                   'ZA',
#                                   'ZM',
#                                   'ZW'],
#             'external_urls': {'spotify': 'https://open.spotify.com/album/2eE8BVirX9VF8Di9hD90iw'},
#             'href': 'https://api.spotify.com/v1/albums/2eE8BVirX9VF8Di9hD90iw',
#             'id': '2eE8BVirX9VF8Di9hD90iw',
#             'images': [{'height': 640,
#                         'url': 'https://i.scdn.co/image/ab67616d0000b2738e55edb69ca44a25b52b17bb',
#                         'width': 640},
#                        {'height': 300,
#                         'url': 'https://i.scdn.co/image/ab67616d00001e028e55edb69ca44a25b52b17bb',
#                         'width': 300},
#                        {'height': 64,
#                         'url': 'https://i.scdn.co/image/ab67616d000048518e55edb69ca44a25b52b17bb',
#                         'width': 64}],
#             'name': 'Come Home The Kids Miss You',
#             'release_date': '2022-05-06',
#             'release_date_precision': 'day',
#             'total_tracks': 15,
#             'type': 'album',
#             'uri': 'spotify:album:2eE8BVirX9VF8Di9hD90iw'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2LIk90788K0zvyj2JJVwkJ'},
#                'href': 'https://api.spotify.com/v1/artists/2LIk90788K0zvyj2JJVwkJ',
#                'id': '2LIk90788K0zvyj2JJVwkJ',
#                'name': 'Jack Harlow',
#                'type': 'artist',
#                'uri': 'spotify:artist:2LIk90788K0zvyj2JJVwkJ'},
#               {'external_urls': {'spotify': 'https://open.spotify.com/artist/55Aa2cqylxrFIXC767Z865'},
#                'href': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865',
#                'id': '55Aa2cqylxrFIXC767Z865',
#                'name': 'Lil Wayne',
#                'type': 'artist',
#                'uri': 'spotify:artist:55Aa2cqylxrFIXC767Z865'}],
#   'available_markets': ['AD',
#                         'AE',
#                         'AG',
#                         'AL',
#                         'AM',
#                         'AO',
#                         'AR',
#                         'AT',
#                         'AU',
#                         'AZ',
#                         'BA',
#                         'BB',
#                         'BD',
#                         'BE',
#                         'BF',
#                         'BG',
#                         'BH',
#                         'BI',
#                         'BJ',
#                         'BN',
#                         'BO',
#                         'BR',
#                         'BS',
#                         'BT',
#                         'BW',
#                         'BZ',
#                         'CA',
#                         'CD',
#                         'CG',
#                         'CH',
#                         'CI',
#                         'CL',
#                         'CM',
#                         'CO',
#                         'CR',
#                         'CV',
#                         'CW',
#                         'CY',
#                         'CZ',
#                         'DE',
#                         'DJ',
#                         'DK',
#                         'DM',
#                         'DO',
#                         'DZ',
#                         'EC',
#                         'EE',
#                         'EG',
#                         'ES',
#                         'FI',
#                         'FJ',
#                         'FM',
#                         'FR',
#                         'GA',
#                         'GB',
#                         'GD',
#                         'GE',
#                         'GH',
#                         'GM',
#                         'GN',
#                         'GQ',
#                         'GR',
#                         'GT',
#                         'GW',
#                         'GY',
#                         'HK',
#                         'HN',
#                         'HR',
#                         'HT',
#                         'HU',
#                         'ID',
#                         'IE',
#                         'IL',
#                         'IN',
#                         'IQ',
#                         'IS',
#                         'IT',
#                         'JM',
#                         'JO',
#                         'JP',
#                         'KE',
#                         'KG',
#                         'KH',
#                         'KI',
#                         'KM',
#                         'KN',
#                         'KR',
#                         'KW',
#                         'KZ',
#                         'LA',
#                         'LB',
#                         'LC',
#                         'LI',
#                         'LK',
#                         'LR',
#                         'LS',
#                         'LT',
#                         'LU',
#                         'LV',
#                         'LY',
#                         'MA',
#                         'MC',
#                         'MD',
#                         'ME',
#                         'MG',
#                         'MH',
#                         'MK',
#                         'ML',
#                         'MN',
#                         'MO',
#                         'MR',
#                         'MT',
#                         'MU',
#                         'MV',
#                         'MW',
#                         'MX',
#                         'MY',
#                         'MZ',
#                         'NA',
#                         'NE',
#                         'NG',
#                         'NI',
#                         'NL',
#                         'NO',
#                         'NP',
#                         'NR',
#                         'NZ',
#                         'OM',
#                         'PA',
#                         'PE',
#                         'PG',
#                         'PH',
#                         'PK',
#                         'PL',
#                         'PS',
#                         'PT',
#                         'PW',
#                         'PY',
#                         'QA',
#                         'RO',
#                         'RS',
#                         'RW',
#                         'SA',
#                         'SB',
#                         'SC',
#                         'SE',
#                         'SG',
#                         'SI',
#                         'SK',
#                         'SL',
#                         'SM',
#                         'SN',
#                         'SR',
#                         'ST',
#                         'SV',
#                         'SZ',
#                         'TD',
#                         'TG',
#                         'TH',
#                         'TJ',
#                         'TL',
#                         'TN',
#                         'TO',
#                         'TR',
#                         'TT',
#                         'TV',
#                         'TW',
#                         'TZ',
#                         'UA',
#                         'UG',
#                         'US',
#                         'UY',
#                         'UZ',
#                         'VC',
#                         'VE',
#                         'VN',
#                         'VU',
#                         'WS',
#                         'XK',
#                         'ZA',
#                         'ZM',
#                         'ZW'],
#   'disc_number': 1,
#   'duration_ms': 222642,
#   'explicit': True,
#   'external_ids': {'isrc': 'USAT22203490'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1hs54MGy1J69I52GvzsrbB'},
#   'href': 'https://api.spotify.com/v1/tracks/1hs54MGy1J69I52GvzsrbB',
#   'id': '1hs54MGy1J69I52GvzsrbB',
#   'is_local': False,
#   'name': 'Poison (feat. Lil Wayne)',
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/dd3db7f0876d814771dc60f1e3517f201e17cbab?cid=eadc1f958a3b40f8866b69c9eda72b86',
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:1hs54MGy1J69I52GvzsrbB'},
#  {'album': {'album_type': 'compilation',
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#                          'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#                          'id': '0LyfQWJT6nXafLPZqxe9Of',
#                          'name': 'Various Artists',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#             'available_markets': ['AE',
#                                   'AL',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'BA',
#                                   'BE',
#                                   'BG',
#                                   'BH',
#                                   'BO',
#                                   'BR',
#                                   'CA',
#                                   'CH',
#                                   'CI',
#                                   'CL',
#                                   'CM',
#                                   'CO',
#                                   'CR',
#                                   'CW',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DK',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
# ...
#   'href': 'https://api.spotify.com/v1/tracks/5VnuU70qRWGrkLPkMLTiD4',
#   'id': '5VnuU70qRWGrkLPkMLTiD4',
#   'is_local': False,
#   'name': 'Istanbul 2022',
#   'popularity': 25,
#   'preview_url': 'https://p.scdn.co/mp3-preview/bc13fd1833a1d5cbb91ddeb1ae5e011fc3db7505?cid=eadc1f958a3b40f8866b69c9eda72b86',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:5VnuU70qRWGrkLPkMLTiD4'},
#  {'album': {'album_type': 'album',
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#                          'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#                          'id': '4q3ewBCX7sLwd24euuV69X',
#                          'name': 'Bad Bunny',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AG',
#                                   'AL',
#                                   'AM',
#                                   'AO',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'AZ',
#                                   'BA',
#                                   'BB',
#                                   'BD',
#                                   'BE',
#                                   'BF',
#                                   'BG',
#                                   'BH',
#                                   'BI',
#                                   'BJ',
#                                   'BN',
#                                   'BO',
#                                   'BR',
#                                   'BS',
#                                   'BT',
#                                   'BW',
#                                   'BY',
#                                   'BZ',
#                                   'CA',
#                                   'CD',
#                                   'CG',
#                                   'CH',
#                                   'CI',
#                                   'CL',
#                                   'CM',
#                                   'CO',
#                                   'CR',
#                                   'CV',
#                                   'CW',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DJ',
#                                   'DK',
#                                   'DM',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FJ',
#                                   'FM',
#                                   'FR',
#                                   'GA',
#                                   'GB',
#                                   'GD',
#                                   'GE',
#                                   'GH',
#                                   'GM',
#                                   'GN',
#                                   'GQ',
#                                   'GR',
#                                   'GT',
#                                   'GW',
#                                   'GY',
#                                   'HK',
#                                   'HN',
#                                   'HR',
#                                   'HT',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IQ',
#                                   'IS',
#                                   'IT',
#                                   'JM',
#                                   'JO',
#                                   'JP',
#                                   'KE',
#                                   'KG',
#                                   'KH',
#                                   'KI',
#                                   'KM',
#                                   'KN',
#                                   'KR',
#                                   'KW',
#                                   'KZ',
#                                   'LA',
#                                   'LB',
#                                   'LC',
#                                   'LI',
#                                   'LK',
#                                   'LR',
#                                   'LS',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'LY',
#                                   'MA',
#                                   'MC',
#                                   'MD',
#                                   'ME',
#                                   'MG',
#                                   'MH',
#                                   'MK',
#                                   'ML',
#                                   'MN',
#                                   'MO',
#                                   'MR',
#                                   'MT',
#                                   'MU',
#                                   'MV',
#                                   'MW',
#                                   'MX',
#                                   'MY',
#                                   'MZ',
#                                   'NA',
#                                   'NE',
#                                   'NG',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NP',
#                                   'NR',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PG',
#                                   'PH',
#                                   'PK',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PW',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'RS',
#                                   'RW',
#                                   'SA',
#                                   'SB',
#                                   'SC',
#                                   'SE',
#                                   'SG',
#                                   'SI',
#                                   'SK',
#                                   'SL',
#                                   'SM',
#                                   'SN',
#                                   'SR',
#                                   'ST',
#                                   'SV',
#                                   'SZ',
#                                   'TD',
#                                   'TG',
#                                   'TH',
#                                   'TJ',
#                                   'TL',
#                                   'TN',
#                                   'TO',
#                                   'TR',
#                                   'TT',
#                                   'TV',
#                                   'TW',
#                                   'TZ',
#                                   'UA',
#                                   'UG',
#                                   'US',
#                                   'UY',
#                                   'UZ',
#                                   'VC',
#                                   'VE',
#                                   'VN',
#                                   'VU',
#                                   'WS',
#                                   'XK',
#                                   'ZA',
#                                   'ZM',
#                                   'ZW'],
#             'external_urls': {'spotify': 'https://open.spotify.com/album/3RQQmkQEvNCY4prGKE6oc5'},
#             'href': 'https://api.spotify.com/v1/albums/3RQQmkQEvNCY4prGKE6oc5',
#             'id': '3RQQmkQEvNCY4prGKE6oc5',
#             'images': [{'height': 640,
#                         'url': 'https://i.scdn.co/image/ab67616d0000b27349d694203245f241a1bcaa72',
#                         'width': 640},
#                        {'height': 300,
#                         'url': 'https://i.scdn.co/image/ab67616d00001e0249d694203245f241a1bcaa72',
#                         'width': 300},
#                        {'height': 64,
#                         'url': 'https://i.scdn.co/image/ab67616d0000485149d694203245f241a1bcaa72',
#                         'width': 64}],
#             'name': 'Un Verano Sin Ti',
#             'release_date': '2022-05-06',
#             'release_date_precision': 'day',
#             'total_tracks': 23,
#             'type': 'album',
#             'uri': 'spotify:album:3RQQmkQEvNCY4prGKE6oc5'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#                'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#                'id': '4q3ewBCX7sLwd24euuV69X',
#                'name': 'Bad Bunny',
#                'type': 'artist',
#                'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#               {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EFisYRi20PTADoJrifHrz'},
#                'href': 'https://api.spotify.com/v1/artists/0EFisYRi20PTADoJrifHrz',
#                'id': '0EFisYRi20PTADoJrifHrz',
#                'name': 'Jhay Cortez',
#                'type': 'artist',
#                'uri': 'spotify:artist:0EFisYRi20PTADoJrifHrz'}],
#   'available_markets': ['AD',
#                         'AE',
#                         'AG',
#                         'AL',
#                         'AM',
#                         'AO',
#                         'AR',
#                         'AT',
#                         'AU',
#                         'AZ',
#                         'BA',
#                         'BB',
#                         'BD',
#                         'BE',
#                         'BF',
#                         'BG',
#                         'BH',
#                         'BI',
#                         'BJ',
#                         'BN',
#                         'BO',
#                         'BR',
#                         'BS',
#                         'BT',
#                         'BW',
#                         'BY',
#                         'BZ',
#                         'CA',
#                         'CD',
#                         'CG',
#                         'CH',
#                         'CI',
#                         'CL',
#                         'CM',
#                         'CO',
#                         'CR',
#                         'CV',
#                         'CW',
#                         'CY',
#                         'CZ',
#                         'DE',
#                         'DJ',
#                         'DK',
#                         'DM',
#                         'DO',
#                         'DZ',
#                         'EC',
#                         'EE',
#                         'EG',
#                         'ES',
#                         'FI',
#                         'FJ',
#                         'FM',
#                         'FR',
#                         'GA',
#                         'GB',
#                         'GD',
#                         'GE',
#                         'GH',
#                         'GM',
#                         'GN',
#                         'GQ',
#                         'GR',
#                         'GT',
#                         'GW',
#                         'GY',
#                         'HK',
#                         'HN',
#                         'HR',
#                         'HT',
#                         'HU',
#                         'ID',
#                         'IE',
#                         'IL',
#                         'IN',
#                         'IQ',
#                         'IS',
#                         'IT',
#                         'JM',
#                         'JO',
#                         'JP',
#                         'KE',
#                         'KG',
#                         'KH',
#                         'KI',
#                         'KM',
#                         'KN',
#                         'KR',
#                         'KW',
#                         'KZ',
#                         'LA',
#                         'LB',
#                         'LC',
#                         'LI',
#                         'LK',
#                         'LR',
#                         'LS',
#                         'LT',
#                         'LU',
#                         'LV',
#                         'LY',
#                         'MA',
#                         'MC',
#                         'MD',
#                         'ME',
#                         'MG',
#                         'MH',
#                         'MK',
#                         'ML',
#                         'MN',
#                         'MO',
#                         'MR',
#                         'MT',
#                         'MU',
#                         'MV',
#                         'MW',
#                         'MX',
#                         'MY',
#                         'MZ',
#                         'NA',
#                         'NE',
#                         'NG',
#                         'NI',
#                         'NL',
#                         'NO',
#                         'NP',
#                         'NR',
#                         'NZ',
#                         'OM',
#                         'PA',
#                         'PE',
#                         'PG',
#                         'PH',
#                         'PK',
#                         'PL',
#                         'PS',
#                         'PT',
#                         'PW',
#                         'PY',
#                         'QA',
#                         'RO',
#                         'RS',
#                         'RW',
#                         'SA',
#                         'SB',
#                         'SC',
#                         'SE',
#                         'SG',
#                         'SI',
#                         'SK',
#                         'SL',
#                         'SM',
#                         'SN',
#                         'SR',
#                         'ST',
#                         'SV',
#                         'SZ',
#                         'TD',
#                         'TG',
#                         'TH',
#                         'TJ',
#                         'TL',
#                         'TN',
#                         'TO',
#                         'TR',
#                         'TT',
#                         'TV',
#                         'TW',
#                         'TZ',
#                         'UA',
#                         'UG',
#                         'US',
#                         'UY',
#                         'UZ',
#                         'VC',
#                         'VE',
#                         'VN',
#                         'VU',
#                         'WS',
#                         'XK',
#                         'ZA',
#                         'ZM',
#                         'ZW'],
#   'disc_number': 1,
#   'duration_ms': 237894,
#   'explicit': False,
#   'external_ids': {'isrc': 'QM6MZ2214881'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/41oY4WCTj5kccfesTVFnvN'},
#   'href': 'https://api.spotify.com/v1/tracks/41oY4WCTj5kccfesTVFnvN',
#   'id': '41oY4WCTj5kccfesTVFnvN',
#   'is_local': False,
#   'name': 'Tarot',
#   'popularity': 93,
#   'preview_url': 'https://p.scdn.co/mp3-preview/db8db5f15768f239548f3499bdd12bfcc6ce063f?cid=eadc1f958a3b40f8866b69c9eda72b86',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:41oY4WCTj5kccfesTVFnvN'}]

# %%
artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2022', type='track',limit=50,offset=i)
    for i,t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])
print(artist_name[0])
print(artist_id[0])
print(track_name[0])
print(track_id[0])
print(track_popularity[0])
# Out:
# Bad Bunny
# 4q3ewBCX7sLwd24euuV69X
# Me Porto Bonito
# 6Sq7ltF9Qa7SNFBsV5Cogx
# 99

# %% [markdown]
# Put the queried data into the Pandas Dataframe.

# %%
import pandas as pd
track_df = pd.DataFrame({
    'artist_name': artist_name,
    'artist_id': artist_id,
    'track_name': track_name,
    'track_id': track_id,
    'track_popularity': track_popularity
})
print(track_df.shape)
track_df.head()
# Out:
# (1000, 5)
#      artist_name               artist_id                track_name  \
# 0      Bad Bunny  4q3ewBCX7sLwd24euuV69X           Me Porto Bonito
# 1      Ish Kevin  27rjDVGfZG4eorQwrZt2ZD            My Year (2022)
# 2    Jack Harlow  2LIk90788K0zvyj2JJVwkJ  Poison (feat. Lil Wayne)
# 3  Years & Years  5vBSrE1xujD2FXYRarbAXc    Desire - Gryffin Remix
# 4           Joji  3MZsBdqDrRTJihTHQrO6Dq             Glimpse of Us
#
#                  track_id  track_popularity
# 0  6Sq7ltF9Qa7SNFBsV5Cogx                99
# 1  4eHkG6yWQ4pD0zqVkV0R5a                21
# 2  1hs54MGy1J69I52GvzsrbB                67
# 3  2ewen7fSmxv0DROX5DK6iM                 1
# 4  6xGruZOHLs39ZbVccQTuPZ                98

# %%
track_df.artist_name.unique().shape
# Out:
# (454,)

# %% [markdown]
# Let’s add information about artists who perform each of the 1000 tracks.

# %%
artist = sp.artist(track_df.artist_id[0])
print(f'track_df.artist_id[0]: {track_df.artist_id[0]}')
pprint.pprint(artist)
# Out:
# track_df.artist_id[0]: 4q3ewBCX7sLwd24euuV69X
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  'followers': {'href': None, 'total': 53047349},
#  'genres': ['latin', 'reggaeton', 'trap latino'],
#  'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#  'id': '4q3ewBCX7sLwd24euuV69X',
#  'images': [{'height': 640,
#              'url': 'https://i.scdn.co/image/ab6761610000e5eb8ee9a6f54dcbd4bc95126b14',
#              'width': 640},
#             {'height': 320,
#              'url': 'https://i.scdn.co/image/ab676161000051748ee9a6f54dcbd4bc95126b14',
#              'width': 320},
#             {'height': 160,
#              'url': 'https://i.scdn.co/image/ab6761610000f1788ee9a6f54dcbd4bc95126b14',
#              'width': 160}],
#  'name': 'Bad Bunny',
#  'popularity': 100,
#  'type': 'artist',
#  'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}

# %%
artist_popularity = []
artist_genres = []
artist_followers = []
# we have duplicates of artists -> better to requests info for unique and left goin with tracks_id
for a_id in track_df.artist_id:
    artist = sp.artist(a_id)
    #print(artist)
    artist_popularity.append(artist['popularity'])
    artist_genres.append(artist['popularity'])
    artist_followers.append(artist['followers']['total'])
print(artist_popularity[0])
print(artist_genres[0])
print(artist_followers[0])
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/Documents/python/env/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     787             retries = retries.increment(
# --> 788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789             )
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     769                 raise value.with_traceback(tb)
# --> 770             raise value
#     771         finally:
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452             raise
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     340             raise ReadTimeoutError(
# --> 341                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342             )
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=120)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-9-41d4569047f8> in <module>
#       4 # we have duplicates of artists -> better to requests info for unique and left goin with tracks_id
#       5 for a_id in track_df.artist_id:
# ----> 6     artist = sp.artist(a_id)
#       7     #print(artist)
#       8     artist_popularity.append(artist['popularity'])
#
# ~/Documents/python/env/lib/python3.7/site-packages/spotipy/client.py in artist(self, artist_id)
#     364
#     365         trid = self._get_id("artist", artist_id)
# --> 366         return self._get("artists/" + trid)
#     367
#     368     def artists(self, artists):
#
# ~/Documents/python/env/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/Documents/python/env/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
# --> 242                 timeout=self.requests_timeout, **args
#     243             )
#     244
#
# ~/Documents/python/env/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/Documents/python/env/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/Documents/python/env/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     576                 raise SSLError(e, request=request)
#     577             elif isinstance(e, ReadTimeoutError):
# --> 578                 raise ReadTimeout(e, request=request)
#     579             elif isinstance(e, _InvalidHeader):
#     580                 raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=120)

# %%
print(artist_popularity[0])
print(artist_genres[0])
print(artist_followers[0])

# %% [markdown]
# Extract artists info only for unique artist in order to reduce number of requests

# %%
unique_artist_id = track_df.artist_id.unique()
artist_popularity = []
artist_genres = []
artist_followers = []

for a_id in unique_artist_id:
    #print(a_id)
    artist = sp.artist(a_id)
    artist_popularity.append(artist['popularity'])
    artist_genres.append(artist['genres'])
    artist_followers.append(artist['followers']['total'])

unique_artist_df = pd.DataFrame({
    'artist_id': unique_artist_id,
    'artist_popularity': artist_popularity,
    'artist_genres': artist_genres,
    'artist_followers': artist_followers
})

unique_artist_df.head()
# Out:
#                 artist_id  artist_popularity  \
# 0  4q3ewBCX7sLwd24euuV69X                100
# 1  27rjDVGfZG4eorQwrZt2ZD                 23
# 2  2LIk90788K0zvyj2JJVwkJ                 84
# 3  5vBSrE1xujD2FXYRarbAXc                 70
# 4  3MZsBdqDrRTJihTHQrO6Dq                 85
#
#                                        artist_genres  artist_followers
# 0                    [latin, reggaeton, trap latino]          53113196
# 1                                  [rwandan hip hop]              7356
# 2  [deep underground hip hop, kentucky hip hop, rap]           2440892
# 3  [dance pop, edm, gauze pop, pop, pop dance, tr...           1935461
# 4                                        [viral pop]           6668828

# %%
unique_artist_df.shape
track_df_1 = track_df.merge(unique_artist_df, on = 'artist_id', how = 'left')
print(track_df.shape)
# Out:
# (1000, 5)

# %%
track_df_1.head()
# Out:
#      artist_name               artist_id                track_name  \
# 0      Bad Bunny  4q3ewBCX7sLwd24euuV69X           Me Porto Bonito
# 1      Ish Kevin  27rjDVGfZG4eorQwrZt2ZD            My Year (2022)
# 2    Jack Harlow  2LIk90788K0zvyj2JJVwkJ  Poison (feat. Lil Wayne)
# 3  Years & Years  5vBSrE1xujD2FXYRarbAXc    Desire - Gryffin Remix
# 4           Joji  3MZsBdqDrRTJihTHQrO6Dq             Glimpse of Us
#
#                  track_id  track_popularity  artist_popularity  \
# 0  6Sq7ltF9Qa7SNFBsV5Cogx                99                100
# 1  4eHkG6yWQ4pD0zqVkV0R5a                21                 23
# 2  1hs54MGy1J69I52GvzsrbB                67                 84
# 3  2ewen7fSmxv0DROX5DK6iM                 1                 70
# 4  6xGruZOHLs39ZbVccQTuPZ                98                 85
#
#                                        artist_genres  artist_followers
# 0                    [latin, reggaeton, trap latino]          53113196
# 1                                  [rwandan hip hop]              7356
# 2  [deep underground hip hop, kentucky hip hop, rap]           2440892
# 3  [dance pop, edm, gauze pop, pop, pop dance, tr...           1935461
# 4                                        [viral pop]           6668828

# %% [markdown]
# Fetch Tracks’ Numerical Features
# We are now going to dive into numerical research of our songs, but first, we need to fetch some data. Luckily, Spotify provides us with thorough insights about 82 million songs, which is just right for our purpose.
#
# First, discover what features contribute to a track’s profile at the Spotify API reference page (https://developer.spotify.com/documentation/web-api/reference/#/operations/get-audio-features).
#
# Second, fetch the tracks’ features and add them to the data frame.

# %%
print(track_df_1.loc[0,['track_id']])
#print(type(track_df_1.loc[0,['track_id']]))
af = sp.audio_features('6Sq7ltF9Qa7SNFBsV5Cogx')
pprint.pprint(af)
type(af)
# Out:
# track_id    6Sq7ltF9Qa7SNFBsV5Cogx
# Name: 0, dtype: object
# [{'acousticness': 0.0901,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'danceability': 0.911,
#   'duration_ms': 178567,
#   'energy': 0.712,
#   'id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#   'instrumentalness': 2.68e-05,
#   'key': 1,
#   'liveness': 0.0933,
#   'loudness': -5.105,
#   'mode': 0,
#   'speechiness': 0.0817,
#   'tempo': 92.005,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx',
#   'valence': 0.425}]
# list

# %%
for item in af:
    print(item)
# Out:
# {'danceability': 0.911, 'energy': 0.712, 'key': 1, 'loudness': -5.105, 'mode': 0, 'speechiness': 0.0817, 'acousticness': 0.0901, 'instrumentalness': 2.68e-05, 'liveness': 0.0933, 'valence': 0.425, 'tempo': 92.005, 'type': 'audio_features', 'id': '6Sq7ltF9Qa7SNFBsV5Cogx', 'uri': 'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx', 'track_href': 'https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7SNFBsV5Cogx', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sq7ltF9Qa7SNFBsV5Cogx', 'duration_ms': 178567, 'time_signature': 4}

# %%
tf_df = pd.DataFrame(columns = ['danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','type','id','uri','track_href','analysis_url','duration_ms','time_signature'])
tf_df.append(af)
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.911   0.712   1    -5.105    0       0.0817        0.0901
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0          0.000027    0.0933    0.425  92.005  audio_features
#
#                        id                                   uri  \
# 0  6Sq7ltF9Qa7SNFBsV5Cogx  spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7S...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6Sq7...      178567
#
#   time_signature
# 0              4

# %%
track_features = []
tf_df = pd.DataFrame(columns = ['danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','type','id','uri','track_href','analysis_url','duration_ms','time_signature'])
for t_id in track_df_1['track_id']:
    af = sp.audio_features(t_id)
    tf_df.append(af, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/Documents/python/env/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     787             retries = retries.increment(
# --> 788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789             )
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     769                 raise value.with_traceback(tb)
# --> 770             raise value
#     771         finally:
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452             raise
#
# ~/Documents/python/env/lib/python3.7/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     340             raise ReadTimeoutError(
# --> 341                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342             )
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=120)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-76-d2b060e61cdf> in <module>
#       2 tf_df = pd.DataFrame(columns = ['danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','type','id','uri','track_href','analysis_url','duration_ms','time_signature'])
#       3 for t_id in track_df_1['track_id']:
# ----> 4     af = sp.audio_features(t_id)
#       5     tf_df.append(af, ignore_index = True)
#
# ~/Documents/python/env/lib/python3.7/site-packages/spotipy/client.py in audio_features(self, tracks)
#    1678         if isinstance(tracks, str):
#    1679             trackid = self._get_id("track", tracks)
# -> 1680             results = self._get("audio-features/?ids=" + trackid)
#    1681         else:
#    1682             tlist = [self._get_id("track", t) for t in tracks]
#
# ~/Documents/python/env/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/Documents/python/env/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
# --> 242                 timeout=self.requests_timeout, **args
#     243             )
#     244
#
# ~/Documents/python/env/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/Documents/python/env/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/Documents/python/env/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     576                 raise SSLError(e, request=request)
#     577             elif isinstance(e, ReadTimeoutError):
# --> 578                 raise ReadTimeout(e, request=request)
#     579             elif isinstance(e, _InvalidHeader):
#     580                 raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=120)

# %%
tf_df.head()
# Out:
# Empty DataFrame
# Columns: [danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature]
# Index: []
